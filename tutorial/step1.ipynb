# %% [markdown]
# # Example 1: Creating Elements

# %% [markdown]
# We define an element with the unique id 'element1', an inlet 'inl1' and an outlet 'outl1'

# %%
from hydpy import Node, Element
e1 = Element("element1",
        inlets="inl1",
        outlets=Node("outl1"))
e1
# Out:
# Element("element1",
#         inlets="inl1",
#         outlets="outl1")

# %% [markdown]
# Now we can already access the different properties of the element:

# %%
e1.name
# Out:
# 'element1'

# %%
e1.inlets
# Out:
# Nodes("inl1")

# %%
e1.outlets
# Out:
# Nodes("outl1")

# %% [markdown]
# The object e1 (of type Element) has more attributes:

# %%
dir(e1)
# Out:
# ['_Device__check_name',
#  '_Element__connections',
#  '_Element__update_group',
#  '__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_del_keywords',
#  '_get_inlets',
#  '_get_inputs',
#  '_get_keywords',
#  '_get_outlets',
#  '_get_outputs',
#  '_get_receivers',
#  '_get_senders',
#  '_inlets',
#  '_inputs',
#  '_keywords',
#  '_model',
#  '_name',
#  '_outlets',
#  '_outputs',
#  '_plot_series',
#  '_query_iosequences',
#  '_receivers',
#  '_senders',
#  '_set_inlets',
#  '_set_inputs',
#  '_set_keywords',
#  '_set_outlets',
#  '_set_outputs',
#  '_set_receivers',
#  '_set_senders',
#  'assignrepr',
#  'clear_all',
#  'collective',
#  'extract_new',
#  'get_handlerclass',
#  'init_model',
#  'inlets',
#  'inputs',
#  'keywords',
#  'load_allseries',
#  'load_factorseries',
#  'load_fluxseries',
#  'load_inputseries',
#  'load_stateseries',
#  'model',
#  'name',
#  'outlets',
#  'outputs',
#  'plot_factorseries',
#  'plot_fluxseries',
#  'plot_inputseries',
#  'plot_stateseries',
#  'prepare_allseries',
#  'prepare_factorseries',
#  'prepare_fluxseries',
#  'prepare_inputseries',
#  'prepare_model',
#  'prepare_stateseries',
#  'query_all',
#  'receivers',
#  'save_allseries',
#  'save_factorseries',
#  'save_fluxseries',
#  'save_inputseries',
#  'save_stateseries',
#  'senders',
#  'variables']

# %% [markdown]
# We can try to access the model attribute (this is the model that is connected to the element):

# %%
e1.model
# Out:
# ---------------------------------------------------------------------------
# AttributeNotReady                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 e1.model
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/hydpy/core/devicetools.py:3144, in Element.model(self)
#    3142 if model:
#    3143     return model
# -> 3144 raise exceptiontools.AttributeNotReady(
#    3145     f"The model object of element `{self.name}` has been requested but not "
#    3146     f"been prepared so far."
#    3147 )
#
# AttributeNotReady: The model object of element `element1` has been requested but not been prepared so far.

# %% [markdown]
# For people who don't program very often, error messages can sometimes cause panic attacks. However, error messages usually provide a good indication of what to do next. Here we can read: 'The model object of element `element1` has been requested but not been prepared so far.' This is right, we haven't assigned a model yet.
